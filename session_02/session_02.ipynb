# %%
price = 10
product = 'Super Snowboard'
Date = '10-Jan-2021'
dimensions = [160, 25, 2]

# %%
# %who returns variable names
# %who
# Out:
# Date	 dimensions	 price	 product

# %%
# %whos returns variable names, types, and information on the data contained
# %whos
# Out:
# Variable     Type    Data/Info
# ------------------------------
# Date         str     10-Jan-2021
# dimensions   list    n=3
# price        int     10
# product      str     Super Snowboard

# %%
# Example: Conditional Statements
age = 18
if age < 13:
    print("You are a child.")
elif age < 20:
    print("You are a teenager.")
else:
    print("You are an adult.")
# Out:
# You are a teenager.

# %%
mobile_price = 103000
if mobile_price > 100000:
  print("This is True Flagship Mobile Phone")

print("This code will run whether the condition is True or False")
print("ABC")
# Out:
# This is True Flagship Mobile Phone
# This code will run whether the condition is True or False
# ABC

# %%
mobile_price = 99000
if mobile_price > 100000:
  print("This is True Flagship Mobile Phone")

print("This code will run whether the condition is True or False")
# Out:
# This code will run whether the condition is True or False

# %%
mobile_price = 99000
if mobile_price > 100000:
  print("This is True Flagship Mobile Phone")

# %%
#Nested condition
mobile_price = 103000
budget = 110000
stock = 0

if budget > mobile_price:
  if stock > 0:
    print("You can afford this device and we have it in stock")
  else:
    print("You can afford this device but we are out of stock")
else:
  print(f"Unfortunately, the device costs more than your {budget}")
# Out:
# You can afford this device but we are out of stock

# %%
# Example: Type Conversion

# Implicit Conversion
num1 = 10  # int
num2 = 5.5  # float
result = num1 + num2  # Automatically converts to float
print("Result:", result, "Type:", type(result))

# Explicit Conversion
age = "25"  # String
age_int = int(age)  # Convert to integer
print("Age as Integer:", age_int, "Type:", type(age_int))
# Out:
# Result: 15.5 Type: <class 'float'>
# Age as Integer: 25 Type: <class 'int'>

# %%
#Converting data into an integer data type

print(type('123')) #initially, '123' refers to string as it is under quatation

int('123') #Using int converts the text string of ‘123’ into an integer data type

#to check the type after conversion

print(type(int('123')))
# Out:
# <class 'str'>
# <class 'int'>

# %%
# Example: Arithmetic Operators

a = 10
b = 3
print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Floor Division:", a // b)  # Rounds down to the nearest integer
print("Modulus:", a % b)  # Remainder after division
print("Exponentiation:", a ** b)  # 10^3
# Out:
# Addition: 13
# Subtraction: 7
# Multiplication: 30
# Division: 3.3333333333333335
# Floor Division: 3
# Modulus: 1
# Exponentiation: 1000

# %%
# Example: Comparison Operators
x = 10
y = 20
print("Is x equal to y?", x == y)
print("Is x greater than y?", x > y)
print("Is x less than or equal to y?", x <= y)
# Out:
# Is x equal to y? False
# Is x greater than y? False
# Is x less than or equal to y? True

# %%
# Example: Logical Operators
is_student = True
is_working = False
print("Is student and working?", is_student and is_working)
print("Is student or working?", is_student or is_working)
print("Is not working?", not is_working)
# Out:
# Is student and working? False
# Is student or working? True
# Is not working? True

# %%
# Example: Numeric Functions
print("Absolute value of -10:", abs(-10))
print("Rounded value of 3.14159:", round(3.14159, 2))  # Round to 2 decimal places
print("Minimum of [5, 2, 8]:", min([5, 2, 8]))
print("Maximum of [5, 2, 8]:", max([5, 2, 8]))
# Out:
# Absolute value of -10: 10
# Rounded value of 3.14159: 3.14
# Minimum of [5, 2, 8]: 2
# Maximum of [5, 2, 8]: 8

# %%
# Example: String Functions
text = "Hello, World!"
print("Length of text:", len(text))
print("Number as string:", str(100))
# Out:
# Length of text: 13
# Number as string: 100

# %%
text = "Python Programming"
print("First character:", text[0])  # Indexing
print("Substring from index 7 to 11:", text[7:12])  # Slicing
print("Every second character:", text[::2])  # Step
print("Reverse string:", text[::-1])  # Reverse
# Out:
# First character: P
# Substring from index 7 to 11: Progr
# Every second character: Pto rgamn
# Reverse string: gnimmargorP nohtyP

# %%
text = "lalin"
print(text[1:4:2])
# Out:
# ai

# %%
# Example: String Methods

text = "  Hello, World!  "
print("Lowercase:", text.lower())
print("Uppercase:", text.upper())
print("Stripped:", text.strip())
print("Replaced:", text.replace("World", "Python"))
print("Split:", text.split(","))  # Splits at comma
print("Joined:", "-".join(["2023", "10", "15"]))  # Joins with hyphen
# Out:
# Lowercase:   hello, world!
# Uppercase:   HELLO, WORLD!
# Stripped: Hello, World!
# Replaced:   Hello, Python!
# Split: ['  Hello', ' World!  ']
# Joined: 2023-10-15

# %%
salary = '$10000'
print(salary)
# Out:
# $10000

# %%
print("Stripped:", salary.strip('$'))
# Out:
# Stripped: 10000

# %%
# Converting to int

type(int(salary.strip('$')))
# Out:
# int

# %%
# Example: F-Strings

name = "Rossi"
age = 34
print(f"My name is {name} and I am {age} years old.")
print(f"Next year, I will be {age + 1} years old.")
# Out:
# My name is Rossi and I am 34 years old.
# Next year, I will be 35 years old.

# %%
def calculate_area(length, width):
    """
    Calculates the area of a rectangle.

    Args:
        length (float): The length of the rectangle.
        width (float): The width of the rectangle.

    Returns:
        float: The calculated area of the rectangle.
    """
    return length * width

# %%
    print(calculate_area(10,20))
# Out:
# 200
